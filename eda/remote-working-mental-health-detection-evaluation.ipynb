# %%
import pandas as pd

# %% [markdown]
# # Dataset tabular overview

# %%
data = pd.read_csv("../data/Impact_of_Remote_Work_on_Mental_Health.csv")

# %%
df
# Out:
#       Age  Gender  Job_Role  Industry  Years_of_Experience  Work_Location  \
# 0      32       2         2         3                   13              0
# 1      40       0         0         4                    3              2
# 2      59       2         6         1                   22              0
# 3      27       1         6         2                   20              1
# 4      49       1         5         0                   32              1
# ...   ...     ...       ...       ...                  ...            ...
# 4995   32       1         5         0                    4              1
# 4996   39       0         5         3                   27              1
# 4997   42       0         5         3                   21              0
# 4998   27       0         5         3                   26              2
# 4999   29       1         2         4                   30              1
#
#       Hours_Worked_Per_Week  Number_of_Virtual_Meetings  \
# ...

# %%
data["Satisfaction_with_Remote_Work"]
# Out:
# 0     Unsatisfied
# 1       Satisfied
# 12        Neutral
# Name: Satisfaction_with_Remote_Work, dtype: object

# %%
data.drop(columns=["Employee_ID"], inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                5000 non-null   int64
#  1   Gender                             5000 non-null   object
#  2   Job_Role                           5000 non-null   object
#  3   Industry                           5000 non-null   object
#  4   Years_of_Experience                5000 non-null   int64
#  5   Work_Location                      5000 non-null   object
#  6   Hours_Worked_Per_Week              5000 non-null   int64
#  7   Number_of_Virtual_Meetings         5000 non-null   int64
#  8   Work_Life_Balance_Rating           5000 non-null   int64
#  9   Stress_Level                       5000 non-null   object
#  10  Mental_Health_Condition            3804 non-null   object
# ...

# %%
numerical_cols = [
    'Age',
    'Years_of_Experience',
    'Hours_Worked_Per_Week',
    'Number_of_Virtual_Meetings',
    'Work_Life_Balance_Rating',
    'Social_Isolation_Rating',
    'Company_Support_for_Remote_Work'
]

correlation_matrix = data[numerical_cols].corr()
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True, cbar_kws={"shrink": .8})
plt.title('Correlation Matrix')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.scatter(data['Age'], data['Years_of_Experience'])
plt.xlabel('Age')
plt.ylabel('Years of Experience')
plt.title('Scatter Plot of Age vs. Years of Experience')
plt.show()

# %%
count_df = df.value_counts(['Region', 'Satisfaction_with_Remote_Work']).reset_index(name='Count')

# Create a bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x='Region', y='Count', hue='Satisfaction_with_Remote_Work', data=count_df)

# Set the title and labels
plt.title('Satisfaction Levels with Remote Work by Region', fontsize=16)
plt.xlabel('Region', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.legend(title='Satisfaction Level')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.scatter(data['Job_Role'], data['Industry'])
plt.xlabel('Job_Role')
plt.ylabel('Industry')
plt.title('Scatter Plot of Age vs. Years of Experience')
plt.show()

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Job_Role', 'Industry', 'Years_of_Experience',
#        'Work_Location', 'Hours_Worked_Per_Week', 'Number_of_Virtual_Meetings',
#        'Work_Life_Balance_Rating', 'Stress_Level', 'Mental_Health_Condition',
#        'Access_to_Mental_Health_Resources', 'Productivity_Change',
#        'Social_Isolation_Rating', 'Satisfaction_with_Remote_Work',
#        'Company_Support_for_Remote_Work', 'Physical_Activity', 'Sleep_Quality',
#        'Region'],
#       dtype='object')

# %%
count_df = data.value_counts(['Job_Role', 'Industry']).reset_index(name='Count')

# Create a bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x='Industry', y='Count', hue='Job_Role', data=count_df)

# Set the title and labels
plt.title('Satisfaction Levels with Remote Work by Region', fontsize=16)
plt.xlabel('Region', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.legend(title='Satisfaction Level')

# Show the plot
plt.tight_layout()
plt.show()

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Job_Role', 'Industry', 'Years_of_Experience',
#        'Work_Location', 'Hours_Worked_Per_Week', 'Number_of_Virtual_Meetings',
#        'Work_Life_Balance_Rating', 'Stress_Level', 'Mental_Health_Condition',
#        'Access_to_Mental_Health_Resources', 'Productivity_Change',
#        'Social_Isolation_Rating', 'Satisfaction_with_Remote_Work',
#        'Company_Support_for_Remote_Work', 'Physical_Activity', 'Sleep_Quality',
#        'Region'],
#       dtype='object')

# %%
count_df = data.value_counts(['Age', 'Years_of_Experience']).reset_index(name='Count')

# Create a bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x='Age', y='Count',
            hue='Years_of_Experience',
            data=count_df)

# Set the title and labels
plt.title('Satisfaction Levels with Remote Work by Region', fontsize=16)
plt.xlabel('Age', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.legend(title='Satisfaction Level')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.scatter(data['Age'], data['Years_of_Experience'])
plt.xlabel('Age')
plt.ylabel('Years_of_Experience')
plt.title('Scatter Plot of Age vs. Years of Experience')
plt.show()

# %%
data =  data[data["Age"]-data["Years_of_Experience"]>=18]

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='Age', y='Years_of_Experience', hue='Gender', palette='coolwarm')
plt.title('Age vs. Years of Experience')
plt.show()

# %%
df.describe()
# Out:
#                Age  Years_of_Experience  Hours_Worked_Per_Week  \
# count  5000.000000          5000.000000            5000.000000
# mean     40.995000            17.810200              39.614600
# std      11.296021            10.020412              11.860194
# min      22.000000             1.000000              20.000000
# 25%      31.000000             9.000000              29.000000
# 50%      41.000000            18.000000              40.000000
# 75%      51.000000            26.000000              50.000000
# max      60.000000            35.000000              60.000000
#
#        Number_of_Virtual_Meetings  Work_Life_Balance_Rating  \
# count                 5000.000000               5000.000000
# mean                     7.559000                  2.984200
# std                      4.636121                  1.410513
# min                      0.000000                  1.000000
# 25%                      4.000000                  2.000000
# ...

# %%
df = df.drop("Employee_ID", axis=1)

# %% [markdown]
# # NULL values encounter

# %%
df.isna().sum()
# Out:
# Age                                     0
# Gender                                  0
# Job_Role                                0
# Industry                                0
# Years_of_Experience                     0
# Work_Location                           0
# Hours_Worked_Per_Week                   0
# Number_of_Virtual_Meetings              0
# Work_Life_Balance_Rating                0
# Stress_Level                            0
# Mental_Health_Condition              1196
# Access_to_Mental_Health_Resources       0
# Productivity_Change                     0
# Social_Isolation_Rating                 0
# Satisfaction_with_Remote_Work           0
# Company_Support_for_Remote_Work         0
# Physical_Activity                    1629
# Sleep_Quality                           0
# Region                                  0
# dtype: int64

# %% [markdown]
# ## Handling NULL values

# %%
df["Physical_Activity"] = df["Physical_Activity"].fillna("None")
df["Mental_Health_Condition"] = df["Mental_Health_Condition"].fillna("None")

# %%
nums = ["Age", "Years_of_Experience", "Hours_Worked_Per_Week", "Number_of_Virtual_Meetings"]
cats = [i for i in df.columns if i not in nums and i != "Mental_Health_Condition"]
cats += ["Mental_Health_Condition"]

# %%
cats
# Out:
# ['Gender',
#  'Job_Role',
#  'Industry',
#  'Work_Location',
#  'Work_Life_Balance_Rating',
#  'Stress_Level',
#  'Access_to_Mental_Health_Resources',
#  'Productivity_Change',
#  'Social_Isolation_Rating',
#  'Satisfaction_with_Remote_Work',
#  'Company_Support_for_Remote_Work',
#  'Physical_Activity',
#  'Sleep_Quality',
#  'Region',
#  'Mental_Health_Condition']

# %% [markdown]
# # Count of employees genders, job features and their quality of life status

# %%
index = 0

for _ in range(3):
    fig, axes = plt.subplots(ncols=5, figsize=(15, 6))
    for i in range(5):
        df[cats[index]].value_counts().plot(kind="bar", ax=axes[i])
        bar_labels(axes[i])
        axes[i].set_title(cats[index].replace('_', ' '))
        index += 1
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Influence of various conditions of mental health status

# %%
index = 0
grouped = df.groupby("Mental_Health_Condition")
for _ in range(7):
    fig, axes = plt.subplots(ncols=2, figsize=(15, 6))
    for i in range(2):
        grouped[cats[index]].value_counts().unstack().plot(kind="bar", ax=axes[i], stacked=True)
        bar_labels(axes[i], 0, "center")
        axes[i].set_title(cats[index].replace('_', ' '))
        index += 1
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Distribution of age, experience, hours worked per weekand number of meetings online
#
# ## General distribution

# %%
fig, axes = plt.subplots(ncols=4, figsize=(15, 6))

for i, j in enumerate(nums):
    sns.histplot(df, x=j, kde=True, ax=axes[i])
    axes[i].set_ylabel("")
    axes[i].set_xlabel("")
    axes[i].set_title(j.replace('_', ' '))
plt.tight_layout()
plt.show()

fig, axes = plt.subplots(ncols=4, figsize=(15, 6))

for i, j in enumerate(nums):
    sns.violinplot(df, x=j, ax=axes[i])
    axes[i].set_ylabel("")
    axes[i].set_xlabel("")
    axes[i].set_title(j.replace('_', ' '))
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Their influence on mental health

# %%
fig, axes = plt.subplots(ncols=4, figsize=(15, 6))

for i, j in enumerate(nums):
    sns.kdeplot(df, x=j, hue=cats[-1], ax=axes[i])
    axes[i].set_ylabel("")
    axes[i].set_xlabel("")
    axes[i].set_title(j.replace('_', ' '))
plt.tight_layout()
plt.show()

fig, axes = plt.subplots(ncols=4, figsize=(15, 6))

for i, j in enumerate(nums):
    sns.violinplot(df, x=cats[-1], y=j, ax=axes[i])
    axes[i].set_ylabel("")
    axes[i].set_xlabel("")
    axes[i].set_title(j.replace('_', ' '))
plt.tight_layout()
plt.show()

# %% [markdown]
# # Encoding categorical features

# %%
le = LabelEncoder()

for i in cats:
    df[i] = le.fit_transform(df[i].values)

# %%
df["Stress_Level"]
# Out:
# 0       2
# 1       2
# 2       2
# 3       0
# 4       0
#        ..
# 4995    0
# 4996    1
# 4997    0
# 4998    1
# 4999    1
# Name: Stress_Level, Length: 5000, dtype: int64

# %%
df["Sleep_Quality"]
# Out:
# 0       1
# 1       1
# 2       2
# 3       2
# 4       0
#        ..
# 4995    0
# 4996    0
# 4997    2
# 4998    0
# 4999    2
# Name: Sleep_Quality, Length: 5000, dtype: int64

# %% [markdown]
# # Scaling dataset

# %%
cats["Satisfaction_with_Remote_Work"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 cats["Satisfaction_with_Remote_Work"]
#
# TypeError: list indices must be integers or slices, not str

# %%
x = df.drop("Satisfaction_with_Remote_Work", axis=1).values
y = df["Satisfaction_with_Remote_Work"].values

scaler = MinMaxScaler()

x = scaler.fit_transform(x)

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=42, test_size=0.2)

# %%
x
# Out:
# array([[0.26315789, 0.66666667, 0.33333333, ..., 1.        , 0.5       ,
#         0.4       ],
#        [0.47368421, 0.        , 0.        , ..., 1.        , 0.5       ,
#         0.2       ],
#        [0.97368421, 0.66666667, 1.        , ..., 0.5       , 1.        ,
#         0.6       ],
#        ...,
#        [0.52631579, 0.        , 0.83333333, ..., 0.        , 1.        ,
#         0.8       ],
#        [0.13157895, 0.        , 0.83333333, ..., 0.        , 0.        ,
#         0.2       ],
#        [0.18421053, 0.33333333, 0.33333333, ..., 0.5       , 1.        ,
#         0.2       ]])

# %%
x_train
# Out:
# array([[0.65789474, 0.66666667, 0.16666667, ..., 1.        , 1.        ,
#         0.8       ],
#        [0.07894737, 0.66666667, 0.66666667, ..., 1.        , 0.5       ,
#         0.        ],
#        [0.63157895, 0.        , 0.5       , ..., 0.        , 0.5       ,
#         0.4       ],
#        ...,
#        [0.15789474, 0.33333333, 1.        , ..., 0.5       , 0.5       ,
#         1.        ],
#        [0.47368421, 0.66666667, 0.66666667, ..., 0.        , 0.        ,
#         0.4       ],
#        [0.34210526, 1.        , 0.5       , ..., 0.5       , 1.        ,
#         0.4       ]])

# %% [markdown]
# # Classification models performance evaluation

# %%
training()
# Out:
# ******************************
# Gradient Boosting
#               precision    recall  f1-score   support
#
#            0       0.32      0.36      0.34       314
#            1       0.37      0.36      0.36       338
#            2       0.38      0.36      0.37       348
#
#     accuracy                           0.36      1000
#    macro avg       0.36      0.36      0.36      1000
# weighted avg       0.36      0.36      0.36      1000
#
#
#
#
# ******************************
# Ada Boost
#               precision    recall  f1-score   support
#
#            0       0.31      0.38      0.34       278
#            1       0.38      0.33      0.35       378
#            2       0.37      0.36      0.37       344
#
#     accuracy                           0.35      1000
#    macro avg       0.35      0.36      0.35      1000
# weighted avg       0.36      0.35      0.35      1000
#
#
#
#
# ******************************
# Support Vector Machine
# ...
